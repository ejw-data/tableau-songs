# %% [markdown]
# ## ETL Song

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
plt.rcParams["figure.figsize"] = (16,9)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)

# %%
# determined encodings with `file --exclude encoding Billboard.csv`
df = pd.read_csv("./data/Billboard.csv", low_memory=False, encoding="ISO-8859-1", parse_dates=['Date Entered', 'Date Peaked'])
df.head()
# Out:
#    Year Yearly Rank Source    Prefix    CH    40    10   PK High Verified  \
# 0  2015         262      h  2015-001  25.0   1.0   0.0  1.0   39      NaN
# 1  2015         298      h  2015-002  34.0  27.0   2.0  2.0   10      NaN
# 2  2015         301      h  2015-003  32.0  25.0  10.0  1.0    7      NaN
# 3  2015         304      h  2015-004  16.0   5.0   0.0  1.0   18      NaN
# 4  2015         308      h  2015-005  20.0   0.0   0.0  1.0   44      NaN
#
#                  Artist       Artist Inverted Featured UnFeatured  \
# 0          Milky Chance          Milky Chance      NaN        NaN
# 1          Fall Out Boy          Fall Out Boy      NaN        NaN
# 2            Nick Jonas           Jonas, Nick      NaN        NaN
# 3        Meghan Trainor       Trainor, Meghan      NaN        NaN
# 4  Florida Georgia Line  Florida Georgia Line      NaN        NaN
#
#                                Album  ... 77th Week 78th Week 79th Week  \
# 0                  Stolen Dance - EP  ...       NaN       NaN       NaN
# 1  American Beauty / American Psycho  ...       NaN       NaN       NaN
# 2        Nick Jonas (Deluxe Version)  ...       NaN       NaN       NaN
# 3                         Title - EP  ...       NaN       NaN       NaN
# 4                      Anything Goes  ...       NaN       NaN       NaN
#
#   80th Week 81st Week 82nd Week  83rd Week 84th Week 85th Week 86th Week  \
# 0       NaN       NaN       NaN        NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN        NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN        NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN        NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN        NaN       NaN       NaN       NaN
#
#   87th Week 88th Week 89th Week 90th Week 91st Week
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 125 columns]
